# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.chdir('D:\EPA\AdvancedDiscrete\BangladeshNeedsHelp8\A3Visualization')
dataFrame = pd.read_csv('vulnerabilityroadN1.csv')
trafficperlane = pd.read_csv('trafficperlaneN1.csv')
dataFrame
# Out:
#      Unnamed: 0 road  LRPName condition  chainage  BridgeFailureLikelihood  \
# 0             0   N1  LRP001a         A     1.800                     0.05
# 1             1   N1  LRP004b         A     4.925                     0.05
# 2             2   N1  LRP008b         A     8.976                     0.05
# 3             3   N1  LRP010a         B    10.543                     0.10
# 4             4   N1  LRP010b         A    10.880                     0.05
# 5             5   N1  LRP010c         A    10.897                     0.05
# 6             6   N1  LRP011a         A    11.296                     0.05
# 7             7   N1  LRP011c         B    11.808                     0.10
# 8             8   N1  LRP012a         A    12.239                     0.05
# 9             9   N1  LRP012b         A    12.253                     0.05
# 10           10   N1  LRP013a         A    12.660                     0.05
# ...

# %%
traffic = trafficperlane[['heavyTruck','mediumTruck','smallTruck']]
HeavyTrucks = traffic[['heavyTruck']]
MediumTrucks = traffic[['mediumTruck']]
SmallTrucks = traffic[['smallTruck']]

# %%
x = trafficperlane['chainage']

y1 = traffic['heavyTruck']
y2 = traffic['mediumTruck']
y3 = traffic['smallTruck']


plt.plot(x, HeavyTrucks, label = 'HeavyTrucks')
plt.plot(x, MediumTrucks, label = 'MediumTrucks')
plt.plot(x, SmallTrucks, label = 'SmallTrucks' )

plt.xlabel('chainage')
plt.ylabel('amount of trucs')
plt.title('Trucks on N1')
plt.grid(True)
plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
help(plt.plot)

t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2*np.pi*t)
plt.plot(t, s)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('About as simple as it gets, folks')
plt.grid(True)
plt.savefig("test.png")
plt.show()
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, **kwargs)
#     Plot lines and/or markers to the
#     :class:`~matplotlib.axes.Axes`.  *args* is a variable length
#     argument, allowing for multiple *x*, *y* pairs with an
#     optional format string.  For example, each of the following is
#     legal::
#
#         plot(x, y)        # plot x and y using default line style and color
#         plot(x, y, 'bo')  # plot x and y using blue circle markers
#         plot(y)           # plot y using x as index array 0..N-1
#         plot(y, 'r+')     # ditto, but with red plusses
#
#     If *x* and/or *y* is 2-dimensional, then the corresponding columns
#     will be plotted.
#
#     If used with labeled data, make sure that the color spec is not
#     included as an element in data, as otherwise the last case
#     ``plot("v","r", data={"v":..., "r":...)``
#     can be interpreted as the first case which would do ``plot(v, r)``
# ...

# %%
extracolum = dataFrame[['TrafficEconomicVulnerability','TotalEconomicVulnerability']]
extra = pd.concat([extracolum,pd.DataFrame(extracolum.sum(axis=1),columns=['Total'])],axis=1)

extra = extra[['Total']]

extra

traffic = traffic.cumsum()
traffic.plot()

traffic['chainage'] = pd.Series(list(range(len(trafficperlane))))
traffic.plot(x='chainage' )
# Out:
#             Total
# 0    14738.850000
# 1     7765.800000
# 2    16429.875000
# 3    17212.250000
# 4    16429.875000
# 5    16429.875000
# 6    16429.875000
# 7     8606.125000
# 8    24377.500000
# 9    24377.500000
# 10   18283.125000
# 11   18283.125000
# 12   18283.125000
# 13   19153.750000
# 14   20024.375000
# 15   18283.125000
# 16   18283.125000
# 17   18283.125000
# 18   19153.750000
# 19   19153.750000
# 20   20024.375000
# 21   18283.125000
# 22   16135.625000
# 23   15402.187500
# 24   15402.187500
# 25   16135.625000
# 26   10268.125000
# 27   10757.083333
# 28   15402.187500
# 29   15402.187500
# ..            ...
# 609   2937.375000
# 610   2937.375000
# 611   3217.125000
# 612   3357.000000
# 613   3077.250000
# 614   2937.375000
# 615   2937.375000
# 616   2937.375000
# 617   3077.250000
# 618   2937.375000
# 619   2937.375000
# 620   2937.375000
# 621   2937.375000
# 622   2937.375000
# 623   2937.375000
# 624   2937.375000
# 625   2937.375000
# 626   2937.375000
# ...

# %%
extra, extra = plt.subplots(figsize = (30,20))

#extra.plot( extra,'-o', ms=10, lw=2, mfc='orange')
#extra.grid()


plt.show()

# %%
N1Trucs, N1Trucs = plt.subplots()

N1Trucs.plot(a, '-o', ms=20, lw=2, alpha=0.7, mfc='orange')
N1Trucs.grid()
#fig.figimage(im, 10, 10, zorder=3)

plt.show()

# %%
from numpy import *

# example data with some peaks:
x = linspace(0,4,1e3)
data = .2*sin(10*x)+ exp(-abs(2-x)**2)

# that's the line, you need:
a = diff(sign(diff(data))).nonzero()[0] + 1 # local min+max
b = (diff(sign(diff(data))) > 0).nonzero()[0] + 1 # local min
c = (diff(sign(diff(data))) < 0).nonzero()[0] + 1 # local max


# graphical output...
from pylab import *
plot(x,data)
plot(x[b], data[b], "o", label="min")
plot(x[c], data[c], "o", label="max")
legend()
show()
